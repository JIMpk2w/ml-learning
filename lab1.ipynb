# %%
# !pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ae/d9/3741b344f57484b423cd22194025a8489992ad9962196a62721ef9980045/pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy<2,>=1.26.0 from https://files.pythonhosted.org/packages/28/75/3b679b41713bb60e2e8f6e2f87be72c971c9e718b1c17b8f8749240ddca8/numpy-1.26.2-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB ? eta 0:00:00
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ---------------------------------------- 341.8/341.8 kB ? eta 0:00:00
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      ------ ------------------------------ 41.0/250.0 kB 326.8 kB/s eta 0:00:01
#      ----------------- ------------------ 122.9/250.0 kB 798.9 kB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

data = pd.read_excel("complaints.xlsx")
data
# Out:
#       เลขรับ กปม.     เลขหนังสือ ลงวันที่\n(คีย์เป็นเลข)  \
# 0           812.0   สผ 0001/6925              2021-05-31
# 1             NaN   สผ 0001/9215              2020-09-21
# 2           558.0   สผ 0001/2468              2022-03-01
# 3          2174.0  สผ 0025/11287              2022-09-23
# 4             NaN    สว 0001/377              2021-01-29
# ...           ...            ...                     ...
# 2151       1508.0   สผ 0001/7115              2022-06-27
# 2152        149.0    สผ 0001/257              2022-01-18
# 2153          NaN   สผ 0001/9215              2020-09-21
# 2154          NaN   สผ 0001/9221              2020-09-21
# 2155          NaN    สว 0001/377              2021-01-29
#
#      วันที่รับเรื่อง\n(คีย์เป็นเลข)  ปีที่  สมัยสามัญ\nครั้งที่  ครั้งที่  \
# 0                        2021-06-21    NaN                  NaN       NaN
# 1                        2020-09-24    2.0                  1.0      18.0
# ...

# %%
#ประเด็นที่ร้องเรียน
#หมวดหมู่ปัญหา (เลือก)
#พื้นที่ / ภูมิภาค
#หน่วยงาน\nที่เกี่ยวข้อง
ans = data.columns
ans
# Out:
# Index(['เลขรับ กปม.', 'เลขหนังสือ', 'ลงวันที่\n(คีย์เป็นเลข)',
#        'วันที่รับเรื่อง\n(คีย์เป็นเลข)', 'ปีที่', 'สมัยสามัญ\nครั้งที่',
#        'ครั้งที่', 'วันที่ประชุม / เรื่องร้องเรียนมา (คีย์เป็นเลข)', 'ประเภท',
#        'ประเภทบุคคล (Auto)', 'พรรคการเมือง', 'ส.ส. เขต / บัญชีรายชื่อ\n(Auto)',
#        'ประเด็นที่ร้องเรียน', 'หมวดหมู่ปัญหา (เลือก)', 'พื้นที่ / ภูมิภาค',
#        'จำนวนส่ง\n(Auto)', 'ข้อพิจารณา\n(เลือก)', 'หน่วยงาน\nที่เกี่ยวข้อง',
#        'รอง นรม. / รมต.นร. ที่กำกับการดำเนินการ',
#        'วันที่แจ้งบัญชา\n(คีย์เป็นเลข)', 'เลขหนังสือ\nแจ้งหน่วยงาน',
#        'Deadline ติดตาม\n(Auto)', 'การติดตาม\n(Auto)', 'สถานะ\n(Auto)',
#        'การทวง', 'เลขที่หนังสือ\n/ลงวันที่', 'วันที่รับ\nหนังสือตอบกลับ',
#        'สถานะคำตอบ\n(เลือก)', 'เลขหนังสือ\nตอบสภาฯ', 'วิเคราะห์คำตอบ', 'คำตอบ',
#        'วันที่ปิดเรื่อง\n(ตอบสภา)\n(คีย์เป็นเลข)', 'Unnamed: 34', 'หมายเหตุ',
#        'การ Update'],
#       dtype='object')

# %%
data = data[["ประเด็นที่ร้องเรียน", "หมวดหมู่ปัญหา (เลือก)", "พื้นที่ / ภูมิภาค", "หน่วยงาน\nที่เกี่ยวข้อง"]]
data
# Out:
#                                     ประเด็นที่ร้องเรียน หมวดหมู่ปัญหา (เลือก)  \
# 0     ขอหน่วยงานที่เกี่ยวข้องวางท่อส่งน้ำสำหรับขยายเ...                   น้ำ
# 1     ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการแก้ไขปัญหาร...                อื่น ๆ
# 2     ขอให้ช่วยเหลือเยียวยาประชาชนที่ได้รับผลกระทบจา...             สาธารณภัย
# 3     ๑. ขออนุญาตตั้งวัดพระพุทธบาทบัวบก ให้เป็นวัดที...  ศิลปะ วัฒนธรรม ศาสนา
# 4     ขอให้รัฐบาลทบทวนการแก้ไขปัญหาประชาคมกระเหรี่ยง...           ที่ดินทำกิน
# ...                                                 ...                   ...
# 2151  ขอให้พิจารณากำกับดูแลและเร่งดำเนินการจัดทำร่าง...              การเมือง
# 2152  ขอให้หน่วยงานที่เกี่ยวข้องบูรณาการการทำงานร่วม...             สวัสดิการ
# 2153  ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการฟื้นฟูเศรษฐ...      เศรษฐกิจ การคลัง
# 2154  ขอความอนุเคราะห์ให้จัดระบบประปาหมู่บ้าน ม.6 บ้...                   น้ำ
# 2155  ขอให้รัฐบาลทบทวนการแก้ไขปัญหาประชาคมกระเหรี่ยง...           ที่ดินทำกิน
#
# ...

# %%
data = data.dropna()
data
# Out:
#                                     ประเด็นที่ร้องเรียน  \
# 0     ขอหน่วยงานที่เกี่ยวข้องวางท่อส่งน้ำสำหรับขยายเ...
# 1     ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการแก้ไขปัญหาร...
# 2     ขอให้ช่วยเหลือเยียวยาประชาชนที่ได้รับผลกระทบจา...
# 4     ขอให้รัฐบาลทบทวนการแก้ไขปัญหาประชาคมกระเหรี่ยง...
# 5     ขอให้พิจารณาดำเนินการแก้ไขปัญหาการลักลอบเล่นพน...
# ...                                                 ...
# 2151  ขอให้พิจารณากำกับดูแลและเร่งดำเนินการจัดทำร่าง...
# 2152  ขอให้หน่วยงานที่เกี่ยวข้องบูรณาการการทำงานร่วม...
# 2153  ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการฟื้นฟูเศรษฐ...
# 2154  ขอความอนุเคราะห์ให้จัดระบบประปาหมู่บ้าน ม.6 บ้...
# 2155  ขอให้รัฐบาลทบทวนการแก้ไขปัญหาประชาคมกระเหรี่ยง...
#
#              หมวดหมู่ปัญหา (เลือก) พื้นที่ / ภูมิภาค หน่วยงาน\nที่เกี่ยวข้อง
# 0                              น้ำ           สระบุรี                    สปน.
# 1                           อื่น ๆ        ทุกภูมิภาค                     กต.
# ...

# %%
pd.DataFrame(data["หมวดหมู่ปัญหา (เลือก)"].unique())
# Out:
#                                         0
# 0                                     น้ำ
# 1                                  อื่น ๆ
# 2                               สาธารณภัย
# 3                             ที่ดินทำกิน
# 4            อาชญากรรม ยาเสพติดและการพนัน
# 5                               สาธารณสุข
# 6                  หนี้สิน เศรษฐกิจฐานราก
# 7                  การบริหารราชการแผ่นดิน
# 8                                การเกษตร
# 9                         ราคาสินค้าเกษตร
# 10                   ศิลปะ วัฒนธรรม ศาสนา
# 11                             อุตสาหกรรม
# 12       การคมนาคม การจราจรหรืออุบัติเหตุ
# 13         โครงสร้างพื้นฐานและสาธารณูปโภค
# 14                               การศึกษา
# 15  ผู้มีอิทธิพล การทุจริตและประพฤติมิชอบ
# 16                       เศรษฐกิจ การคลัง
# 17             กฎหมายและกระบวนการยุติธรรม
# 18                          การต่างประเทศ
# 19                 โทรคมนาคมและการสื่อสาร
# 20                          การท่องเที่ยว
# ...

# %%
data["หมวดหมู่ปัญหา (เลือก)"].unique().size
# Out:
# 34

# %%
data["พื้นที่ / ภูมิภาค"].unique().size
# Out:
# 116

# %%
data["พื้นที่ / ภูมิภาค"].unique()
# Out:
# array(['สระบุรี', 'ทุกภูมิภาค', 'สุพรรณบุรี', 'เพชรบุรี', 'กรุงเทพมหานคร',
#        'จันทบุรี', 'น่าน', 'ประจวบคีรีขันธ์', 'ลำพูน', 'ระยอง',
#        'เชียงใหม่', 'มุกดาหาร', 'ตาก', 'ขอนแก่น', 'พัทลุง', 'ชัยภูมิ',
#        'นครราชสีมา', 'ภาคตะวันออก', 'อุบลราชธานี', 'มหาสารคาม',
#        'กาฬสินธุ์,ร้อยเอ็ด', 'นครศรีธรรมราช', 'นราธิวาส', 'ศรีสะเกษ',
#        'สมุทรปราการ', 'ภูเก็ต', 'สมุทรสงคราม', 'ปทุมธานี', 'ยะลา',
#        'ปทุมธานี/อยุธยา', 'พระนครศรีอยุธยา, ลพบุรี, สระบุรี', 'นนทบุรี',
#        'นครพนม, อุดรธานี, มหาสารคาม, มุกดาหาร, สกลนคร', 'พิษณุโลก',
#        'พระนครศรีอยุธยา', 'นครปฐม', 'สมุทรสาคร', 'เชียงราย', 'ชลบุรี',
#        'ตราด', 'สุราษฎร์ธานี', 'พัทลุง, สงขลา', 'นโยบายภาพรวม',
#        'เพชรบูรณ์', 'ราชบุรี', 'สงขลา', 'กระบี่', 'ลพบุรี', 'ปราจีนบุรี',
#        'กำแพงเพชร', 'สกลนคร', 'สุรินทร์',
#        'นราธิวาส, ปัตตานี, ยะลา, สงขลา', 'อุดรธานี',
#        'ยะลา, ปัตตานี, นราธิวาส, สงขลา', 'สระแก้ว', 'ฉะเชิงเทรา',
# ...

# %%
data["หน่วยงาน\nที่เกี่ยวข้อง"].unique().size
# Out:
# 72

# %%
data["หน่วยงาน\nที่เกี่ยวข้อง"].value_counts()
# Out:
# หน่วยงาน\nที่เกี่ยวข้อง
# มท.                                                  343
# ตร.                                                  196
# สปน.                                                 176
# กษ.                                                  171
# สธ.                                                  148
#                                                     ...
# สคบ.                                                   1
# กทบ.                                                   1
# คกก. ตรวจสอบการกระทำความผิดกรณีสถานที่เล่นการพนัน      1
# ผบ.ตร.                                                 1
# เลย                                                    1
# Name: count, Length: 72, dtype: int64

# %%
data.to_csv("complaints.csv", encoding="utf-8-sig")
